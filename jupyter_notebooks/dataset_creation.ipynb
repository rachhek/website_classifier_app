# %% [markdown]
# # Dataset Creation
# In this notebook, I will create a dataset that will be used for training the website classifier.
# The website collection with labelled categories is collected from https://www.kaggle.com/patanjalichin1/dmoztoolsnet-categorical-data
# I will use BeautifulSoup to parse the HTML content of the page and use requests library to fetch the page

# %%
from bs4 import BeautifulSoup
import bs4 as bs4
from urllib.parse import urlparse
import requests
from collections import Counter
import pandas as pd
import os

# %% [markdown]
# ## Building a Scraper Class that matches our requirement

# %%
class ScraperTool:
    def visit_url(self, website_url):
        '''
        Visit URL. Download the Content. Initialize the beautifulsoup object. Call parsing methods. Return Series object.
        '''
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36'}
        content = requests.get(website_url,headers=headers,timeout=10).content
        
        #lxml is apparently faster than other settings.
        soup = BeautifulSoup(content, "lxml")
        result = {
            "website_url": website_url,
            "website_name": self.get_website_name(website_url),
            "title_tag_content": self.get_html_title_tag(soup),
            "meta_tag_content": self.get_html_meta_tags(soup),
            "headings_content": self.get_html_heading_tags(soup),
            "html_text_content": self.get_text_content(soup)
        }
        #get_tag_count returns a dynamic dictionary. That is why we update the dictionary with a separate update command.
        result.update(self.get_tag_count(soup))
        
        #Convert to Series object and return
        return pd.Series(result)
    
    def get_website_name(self,website_url):
        '''
        Example: returns "google" from "www.google.com"
        '''
        return "".join(urlparse(website_url).netloc.split(".")[-2])
    
    def get_html_title_tag(self,soup):
        '''Return the text content of <title> tag from a webpage'''
        return '. '.join(soup.title.contents)
    
    def get_html_meta_tags(self,soup):
        '''Returns the text content of <meta> tags related to keywords and description from a webpage'''
        tags = soup.find_all(lambda tag: (tag.name=="meta") & (tag.has_attr('name') & (tag.has_attr('content'))))
        content = [str(tag["content"]) for tag in tags if tag["name"] in ['keywords','description']]
        return ' '.join(content)
    
    def get_html_heading_tags(self,soup):
        '''returns the text content of heading tags. The assumption is that headings might contain relatively important text.'''
        tags = soup.find_all(["h1","h2","h3","h4","h5","h6"])
        content = [" ".join(tag.stripped_strings) for tag in tags]
        return ' '.join(content)
    
    def get_text_content(self,soup):
        '''returns the text content of the whole page with some exception to tags. See tags_to_ignore.'''
        tags_to_ignore = ['style', 'script', 'head', 'title', 'meta', '[document]',"h1","h2","h3","h4","h5","h6","noscript"]
        tags = soup.find_all(text=True)
        result = []
        for tag in tags:
            stripped_tag = tag.strip()
            if tag.parent.name not in tags_to_ignore\
                and isinstance(tag, bs4.element.Comment)==False\
                and not stripped_tag.isnumeric()\
                and len(stripped_tag)>0:
                result.append(stripped_tag)
        return ' '.join(result)

    def get_tag_count(self,soup):
        '''returns a dictionary with the frequency of tag for every unique tag found in the page.'''
        tags = soup.find_all()
        return dict(Counter(["tag_count_" + tag.name for tag in tags]))

# %% [markdown]
# ## Example of using the class to scrape some websites

# %%
scraperTool = ScraperTool()
urls = ["https://cnn.com/","https://sastodeal.com"]
series_list = []
for url in urls:
    series_list.append(scraperTool.visit_url(url))
pd.DataFrame(pd.concat(series_list,axis=1,sort=False)).T
# Out:
#              website_url website_name  \
# 0       https://cnn.com/          cnn
# 1  https://sastodeal.com    sastodeal
#
#                                    title_tag_content  \
# 0  CNN International - Breaking News, US News, Wo...
# 1  Online shopping in Nepal | Buy online in Nepal...
#
#                                     meta_tag_content  \
# 0  Find the latest breaking news and information ...
# 1  The biggest online shopping store in kathmandu...
#
#                                     headings_content  \
# 0
# 1  My Cart My Account Real email address is requi...
#
#                                    html_text_content tag_count_html  \
# 0  World US Politics Business Health Entertainmen...              1
# 1  JavaScript seems to be disabled in your browse...              1
#
#   tag_count_head tag_count_meta tag_count_link     ...      tag_count_main  \
# 0              1             22             58     ...                 NaN
# 1              1              9              5     ...                   1
#
#   tag_count_h2 tag_count_fieldset tag_count_select tag_count_option  \
# 0          NaN                NaN              NaN              NaN
# 1            4                  5                1                4
#
#   tag_count_figure tag_count_h3 tag_count_small tag_count_h4 tag_count_br
# 0              NaN          NaN             NaN          NaN          NaN
# 1               32            2               9           13            3
#
# [2 rows x 48 columns]

# %% [markdown]
# # Combining the list of websites into a dataframe

# %%
data_directory = "data/"
files = os.listdir(data_directory)
df_list = []
for file in files:
    df_list.append(pd.read_csv(data_directory+file))
websites_df = pd.concat(df_list,sort=False)

# %%
websites_df.shape, websites_df.columns
# Out:
# ((825848, 7),
#  Index(['Description', 'Title', 'URL', 'Sites', 'CCat', 'MCat', 'SCat'], dtype='object'))

# %% [markdown]
# ### Saving to Pickle for later user

# %%
websites_df.to_pickle("dmoz_websites_collection.pkl")

# %% [markdown]
# ## Loading data from pickle

# %%
websites_df = pd.read_pickle("dmoz_websites_collection.pkl")

# %%
websites_df.shape
# Out:
# (825848, 7)

# %% [markdown]
# ## Let's create a subset of the dataset. Randomly selecting 100 websites from each Main category.

# %%
website_main_categories = websites_df["MCat"].unique()

# %%
websites_df_subset = []
for category in website_main_categories:
    websites_df_subset.append(websites_df[websites_df["MCat"]==category].sample(100))
websites_df_subset = pd.concat(websites_df_subset,sort=False).reset_index()

# %%
len(websites_df_subset["Sites"].unique())
# Out:
# 1100

# %% [markdown]
# ## Let's loop through these websites, scrape them and add them to the dataframe

# %%
websites_df_subset.shape
# Out:
# (1100, 8)

# %%
series_list = []
for index,row in websites_df_subset.iterrows():
    print("Scraping URL: ",row["Sites"])
    try:
        series_list.append(scraperTool.visit_url(row["Sites"]))
        print("Scraping success = True. Url: ",row["Sites"])
    except Exception as e:
        print("Scraping success = False.Url: ",row["Sites"])
        print(str(e))
        print("\n")
# Out:
# Scraping URL:  http://allreaders.com/movie-review-summary/independence-day-3602
# Scraping success = True. Url:  http://allreaders.com/movie-review-summary/independence-day-3602
# Scraping URL:  http://www.imdb.com/name/nm0177933/
# Scraping success = True. Url:  http://www.imdb.com/name/nm0177933/
# Scraping URL:  http://www.carterusm.co.uk/
# Scraping success = True. Url:  http://www.carterusm.co.uk/
# Scraping URL:  http://www.voicesofafrica.net/
# Scraping success = True. Url:  http://www.voicesofafrica.net/
# Scraping URL:  http://www.jessebaxter.com/
# Scraping success = True. Url:  http://www.jessebaxter.com/
# Scraping URL:  http://www.tupac.be/
# Scraping success = True. Url:  http://www.tupac.be/
# Scraping URL:  http://www.melodymenchorus.org/
# Scraping success = True. Url:  http://www.melodymenchorus.org/
# Scraping URL:  http://bulgakov.stormloader.com/
# Scraping success = True. Url:  http://bulgakov.stormloader.com/
# Scraping URL:  http://www.idapostle.com/
# Scraping success = True. Url:  http://www.idapostle.com/
# Scraping URL:  http://www.vancouveropera.ca/
# Scraping success = True. Url:  http://www.vancouveropera.ca/
# Scraping URL:  http://www.jazzradio.net/
# Scraping success = True. Url:  http://www.jazzradio.net/
# Scraping URL:  http://www.ign.com/movies/pineapple-express/theater-925261
# Scraping success = True. Url:  http://www.ign.com/movies/pineapple-express/theater-925261
# Scraping URL:  http://www.creatingkeepsakes.com/
# Scraping success = False.Url:  http://www.creatingkeepsakes.com/
# HTTPConnectionPool(host='www.creatingkeepsakes.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000016804F3B518>, 'Connection to www.creatingkeepsakes.com timed out. (connect timeout=10)'))
#
#
# Scraping URL:  http://www.everypoet.com/archive/poetry/Wallace_Stevens/wallace_stevens_a_high_toned_old_christian_woman.htm
# Scraping success = True. Url:  http://www.everypoet.com/archive/poetry/Wallace_Stevens/wallace_stevens_a_high_toned_old_christian_woman.htm
# Scraping URL:  http://www.academybrassquintet.com/
# Scraping success = True. Url:  http://www.academybrassquintet.com/
# Scraping URL:  http://www.tvguide.com/movies/harry-met-sally/127585/
# Scraping success = True. Url:  http://www.tvguide.com/movies/harry-met-sally/127585/
# Scraping URL:  http://imdb.com/title/tt0135707/
# Scraping success = True. Url:  http://imdb.com/title/tt0135707/
# Scraping URL:  http://www.polarisdance.org/
# Scraping success = True. Url:  http://www.polarisdance.org/
# Scraping URL:  http://www.tunefruit.com/
# Scraping success = True. Url:  http://www.tunefruit.com/
# Scraping URL:  http://www.bucket-boys.com/
# Scraping success = True. Url:  http://www.bucket-boys.com/
# Scraping URL:  http://www.espace.org/
# Scraping success = True. Url:  http://www.espace.org/
# Scraping URL:  http://www.franciscozuniga.org/
# Scraping success = True. Url:  http://www.franciscozuniga.org/
# Scraping URL:  http://www.carolstephenson.com/
# Scraping success = True. Url:  http://www.carolstephenson.com/
# Scraping URL:  http://www.bartleby.com/people/Cicero-orat.html
# Scraping success = True. Url:  http://www.bartleby.com/people/Cicero-orat.html
# Scraping URL:  http://westedgeopera.org/
# Scraping success = True. Url:  http://westedgeopera.org/
# Scraping URL:  http://www.filmtracks.com/titles/timeline.html
# Scraping success = True. Url:  http://www.filmtracks.com/titles/timeline.html
# Scraping URL:  http://stromata.tripod.com/id317.htm
# Scraping success = True. Url:  http://stromata.tripod.com/id317.htm
# Scraping URL:  http://www.pachinkostudio.com/
# Scraping success = True. Url:  http://www.pachinkostudio.com/
# Scraping URL:  http://www.klingon.org/smboard/
# Scraping success = False.Url:  http://www.klingon.org/smboard/
# 'NoneType' object has no attribute 'contents'
#
#
# Scraping URL:  http://www.angelfire.com/anime3/allucia/
# Scraping success = True. Url:  http://www.angelfire.com/anime3/allucia/
com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001686BB5FF98>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
#
#
# Scraping URL:  http://www.fiveways-bearings.co.uk/
# Scraping success = True. Url:  http://www.fiveways-bearings.co.uk/
# Scraping URL:  http://www.didsbury.com/
# Scraping success = True. Url:  http://www.didsbury.com/
# Scraping URL:  http://www.prattandlambert.com/
# Scraping success = True. Url:  http://www.prattandlambert.com/
# Scraping URL:  http://www.kdachem.com/
# Scraping success = True. Url:  http://www.kdachem.com/
# Scraping URL:  http://www.mooringsfractional.com/
# Scraping success = True. Url:  http://www.mooringsfractional.com/
# Scraping URL:  http://www.istt.com/
# Scraping success = True. Url:  http://www.istt.com/
# Scraping URL:  http://www.acumen-bcp.co.uk/
# Scraping success = True. Url:  http://www.acumen-bcp.co.uk/
# Scraping URL:  http://www.venturefour.com/
# Scraping success = True. Url:  http://www.venturefour.com/
# Scraping URL:  http://www.canena.org/
# Scraping success = True. Url:  http://www.canena.org/
# Scraping URL:  http://gspl.co.in/
# Scraping success = True. Url:  http://gspl.co.in/
# Scraping URL:  http://www.guymerbailey.com.au/
# Scraping success = True. Url:  http://www.guymerbailey.com.au/
# Scraping URL:  http://www.eyeforenergy.com/
# Scraping success = True. Url:  http://www.eyeforenergy.com/
# Scraping URL:  http://www.woodandpartners.com/
# Scraping success = True. Url:  http://www.woodandpartners.com/
# Scraping URL:  http://www.eaw.com/
# Scraping success = True. Url:  http://www.eaw.com/
# Scraping URL:  http://www.scottrade.com/
# Scraping success = True. Url:  http://www.scottrade.com/
# Scraping URL:  http://www.jinevabridal.com/
# Scraping success = True. Url:  http://www.jinevabridal.com/
# Scraping URL:  http://www.apmsinc.com/
# Scraping success = True. Url:  http://www.apmsinc.com/
# Scraping URL:  http://www.bankatcommerce.com/
# Scraping success = True. Url:  http://www.bankatcommerce.com/
# Scraping URL:  http://www.ljsilvers.com/
# Scraping success = True. Url:  http://www.ljsilvers.com/
# Scraping URL:  http://www.nianticseal.com/
# Scraping success = True. Url:  http://www.nianticseal.com/
# Scraping URL:  http://www.propaneusa.com/
# Scraping success = False.Url:  http://www.propaneusa.com/
# 'NoneType' object has no attribute 'contents'
#
#
# Scraping URL:  http://www.pyramidflowers.com/
# Scraping success = True. Url:  http://www.pyramidflowers.com/
# Scraping URL:  http://www.kmc-cpa.com/
# Scraping success = True. Url:  http://www.kmc-cpa.com/
# Scraping URL:  http://www.arabtrans.co.uk/
# Scraping success = True. Url:  http://www.arabtrans.co.uk/
# Scraping URL:  http://www.jeffkrotz.com/
# Scraping success = True. Url:  http://www.jeffkrotz.com/
# Scraping URL:  http://www.dataperceptions.co.uk/
# Scraping success = True. Url:  http://www.dataperceptions.co.uk/
# Scraping URL:  http://www.iaf-bs.de/
# Scraping success = True. Url:  http://www.iaf-bs.de/
# Scraping URL:  http://www.datalex.com/
# Scraping success = False.Url:  http://www.datalex.com/
# HTTPSConnectionPool(host='www.datalex.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
#
# Scraping URL:  http://www.foamtechniques.co.uk/
# Scraping success = True. Url:  http://www.foamtechniques.co.uk/
# Scraping URL:  http://www.chester-jensen.com/
# Scraping success = True. Url:  http://www.chester-jensen.com/
# Scraping URL:  http://www.jana-williams.com/
# Scraping success = True. Url:  http://www.jana-williams.com/
# Scraping URL:  http://www.robomedia.com/
# Scraping success = True. Url:  http://www.robomedia.com/
# Scraping URL:  http://www.firstib.com/
# Scraping success = True. Url:  http://www.firstib.com/
# Scraping URL:  http://www.ipmd.net/
# Scraping success = True. Url:  http://www.ipmd.net/
# Scraping URL:  http://nationalvo.com/
# Scraping success = True. Url:  http://nationalvo.com/
# Scraping URL:  http://www.cbsales.com/
# Scraping success = True. Url:  http://www.cbsales.com/
# Scraping URL:  http://carousell.com/
# Scraping success = True. Url:  http://carousell.com/
# Scraping URL:  http://www.aseko.cz/
# Scraping success = True. Url:  http://www.aseko.cz/
# Scraping URL:  http://www.eseco-speedmaster.com/
# Scraping success = True. Url:  http://www.eseco-speedmaster.com/
# Scraping URL:  http://www.mafcu.org/
# Scraping success = True. Url:  http://www.mafcu.org/
# Scraping URL:  http://www.actionmold.com/
# Scraping success = True. Url:  http://www.actionmold.com/
# Scraping URL:  http://www.etchedimages.com/
# Scraping success = True. Url:  http://www.etchedimages.com/
# Scraping URL:  http://www.es-cu.com/
# Scraping success = True. Url:  http://www.es-cu.com/
# Scraping URL:  http://www.healthyhay4horses.com/
# Scraping success = True. Url:  http://www.healthyhay4horses.com/
# Scraping URL:  http://www.oldhambros.co.uk/
# Scraping success = True. Url:  http://www.oldhambros.co.uk/
# Scraping URL:  http://www.kaddy.com/
# Scraping success = False.Url:  http://www.kaddy.com/
# HTTPConnectionPool(host='www.kaddy.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000168036356D8>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed',))
#
#
# Scraping URL:  http://www.stoffel.com/
# Scraping success = True. Url:  http://www.stoffel.com/
# Scraping URL:  http://camping-trailers.com/
# Scraping success = True. Url:  http://camping-trailers.com/
# Scraping URL:  http://www.empire-aviation.com/
# Scraping success = True. Url:  http://www.empire-aviation.com/
# Scraping URL:  http://www.acecasters.com/
# Scraping success = True. Url:  http://www.acecasters.com/
# Scraping URL:  http://www.auroralife.com/
# Scraping success = True. Url:  http://www.auroralife.com/
# Scraping URL:  http://www.acuteservices.com/
# Scraping success = True. Url:  http://www.acuteservices.com/
# Scraping URL:  http://www.lib.unc.edu/stories/cotton/about/
# Scraping success = True. Url:  http://www.lib.unc.edu/stories/cotton/about/
# Scraping URL:  http://www.legalfilings.com/
# Scraping success = True. Url:  http://www.legalfilings.com/
# Scraping URL:  http://www.marionengineering.com/
# Scraping success = True. Url:  http://www.marionengineering.com/
# Scraping URL:  http://www.mprconsulting.com/
# Scraping success = False.Url:  http://www.mprconsulting.com/
# HTTPConnectionPool(host='www.mprconsulting.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000016803CE9278>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed',))
#
#
# Scraping URL:  http://www.phaseware.com/
# Scraping success = True. Url:  http://www.phaseware.com/
# Scraping URL:  http://www.wbranson.com/
# Scraping success = True. Url:  http://www.wbranson.com/
# Scraping URL:  http://www.british-assessment.co.uk/
# Scraping success = False.Url:  http://www.british-assessment.co.uk/
# 'NoneType' object has no attribute 'contents'
#
#
# Scraping URL:  http://www.uglyducklinglures.com/
# Scraping success = True. Url:  http://www.uglyducklinglures.com/
# Scraping URL:  http://www.karmahill.com/
# Scraping success = True. Url:  http://www.karmahill.com/
# Scraping URL:  http://www.everyvalve.com/
# Scraping success = True. Url:  http://www.everyvalve.com/
# Scraping URL:  http://www.siebertnet.com/
# Scraping success = True. Url:  http://www.siebertnet.com/
# Scraping URL:  http://www.capcityspeakers.com/
# Scraping success = True. Url:  http://www.capcityspeakers.com/
# Scraping URL:  http://umccorp.com/
# Scraping success = True. Url:  http://umccorp.com/
# Scraping URL:  http://www.activeinsurance.com/
# Scraping success = True. Url:  http://www.activeinsurance.com/
# Scraping URL:  http://imdavid.com/
# Scraping success = True. Url:  http://imdavid.com/
# Scraping URL:  http://www.forta-ferro.com/
# Scraping success = True. Url:  http://www.forta-ferro.com/
# Scraping URL:  http://www.art-n-glass.com/
# Scraping success = True. Url:  http://www.art-n-glass.com/
# Scraping URL:  http://ronrezek.com/
# Scraping success = False.Url:  http://ronrezek.com/
# HTTPConnectionPool(host='ronrezek.com', port=80): Read timed out. (read timeout=10)
#
#
# Scraping URL:  http://www.lehighgroup.com/
# Scraping success = True. Url:  http://www.lehighgroup.com/
# Scraping URL:  http://www.sahrakav.com/
# Scraping success = True. Url:  http://www.sahrakav.com/
# Scraping URL:  http://www.carpenterloghomes.com/
# Scraping success = True. Url:  http://www.carpenterloghomes.com/
# Scraping URL:  http://www.accordintl.com/
# Scraping success = True. Url:  http://www.accordintl.com/
# Scraping URL:  http://www.sigma-systems.com/
# Scraping success = True. Url:  http://www.sigma-systems.com/
# Scraping URL:  http://www.transpluscorp.com/
# Scraping success = True. Url:  http://www.transpluscorp.com/
# Scraping URL:  http://www.sotecma.com/
# Scraping success = True. Url:  http://www.sotecma.com/
# Scraping URL:  http://www.alphatronmarine.nl/
# Scraping success = False.Url:  http://www.alphatronmarine.nl/
# HTTPConnectionPool(host='www.alphatronmarine.nl', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000016803705198>, 'Connection to www.alphatronmarine.nl timed out. (connect timeout=10)'))
#
#
# Scraping URL:  http://www.cactusclimbing.co.nz/
# Scraping success = True. Url:  http://www.cactusclimbing.co.nz/
# Scraping URL:  http://www.kovindesign.com/
# Scraping success = False.Url:  http://www.kovindesign.com/
# 'NoneType' object has no attribute 'contents'
#
#
# Scraping URL:  http://www.expeditersonline.com/
# Scraping success = True. Url:  http://www.expeditersonline.com/
# Scraping URL:  http://www.geobin123.com/
# Scraping success = True. Url:  http://www.geobin123.com/
# Scraping URL:  http://www.mvmills.com/content/history-of-mount-vernon
# Scraping success = True. Url:  http://www.mvmills.com/content/history-of-mount-vernon
# Scraping URL:  http://www.digitalpowermeters.com/
# Scraping success = True. Url:  http://www.digitalpowermeters.com/
# Scraping URL:  http://edgetune.com/
# Scraping success = True. Url:  http://edgetune.com/
# Scraping URL:  http://www.eckhoffdevries.com/
# Scraping success = True. Url:  http://www.eckhoffdevries.com/
# Scraping URL:  http://www.venrock.com/
# Scraping success = True. Url:  http://www.venrock.com/
# Scraping URL:  http://www.artesianwater.com/
# Scraping success = True. Url:  http://www.artesianwater.com/
# Scraping URL:  http://www.daveycontinuity.com/
# Scraping success = True. Url:  http://www.daveycontinuity.com/
# Scraping URL:  http://www.mcdi.com/
# Scraping success = True. Url:  http://www.mcdi.com/
# Scraping URL:  http://www.landdesign.com/
# Scraping success = True. Url:  http://www.landdesign.com/
# Scraping URL:  http://www.atis-sk.ca/
# Scraping success = False.Url:  http://www.atis-sk.ca/
# HTTPConnectionPool(host='www.atis-sk.ca', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000168050B2E48>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed',))
#
#
# Scraping URL:  http://www.naplesvideography.com/
# Scraping success = True. Url:  http://www.naplesvideography.com/
# Scraping URL:  http://www.spongobongo.com/her9997.htm
# Scraping success = False.Url:  http://www.spongobongo.com/her9997.htm
# HTTPSConnectionPool(host='www.furniture.com', port=443): Max retries exceeded with url: /rugs/guide/oriental/turkmen/ersari (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
#
# Scraping URL:  http://www.sunriseequipments.com/
# Scraping success = True. Url:  http://www.sunriseequipments.com/
# Scraping URL:  http://www.davidjamesonarchitect.com/
# Scraping success = True. Url:  http://www.davidjamesonarchitect.com/
# Scraping URL:  http://home.btclick.com/energbco/index.htm
# Scraping success = False.Url:  http://home.btclick.com/energbco/index.htm
# 'NoneType' object has no attribute 'contents'
#
#
# Scraping URL:  http://www.elwoodstudio.com/
# Scraping success = True. Url:  http://www.elwoodstudio.com/
# Scraping URL:  http://www.lindstrand.co.uk/
# Scraping success = False.Url:  http://www.lindstrand.co.uk/
# HTTPConnectionPool(host='www.lindstrand.co.uk', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000016803993518>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed',))
#
#
# Scraping URL:  http://www.gqaconsulting.com/
# Scraping success = False.Url:  http://www.gqaconsulting.com/
# HTTPConnectionPool(host='www.gqaconsulting.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000016803993470>, 'Connection to www.gqaconsulting.com timed out. (connect timeout=10)'))
#
#
# Scraping URL:  http://www.atarimagazines.com/compute/
# Scraping success = True. Url:  http://www.atarimagazines.com/compute/
# Scraping URL:  http://batch.fcodersoft.com/2wbmp/
# Scraping success = False.Url:  http://batch.fcodersoft.com/2wbmp/
# HTTPConnectionPool(host='batch.fcodersoft.com', port=80): Max retries exceeded with url: /2wbmp/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001680398C6A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
#
#
# Scraping URL:  http://www.vfrazee.com/ms-dos/6.22/help/
# Scraping success = True. Url:  http://www.vfrazee.com/ms-dos/6.22/help/
# Scraping URL:  http://www.faqs.org/faqs/aix-faq/
# Scraping success = True. Url:  http://www.faqs.org/faqs/aix-faq/
# Scraping URL:  http://www.bluechiptechnology.co.uk/
# Scraping success = True. Url:  http://www.bluechiptechnology.co.uk/
# Scraping URL:  http://tools.ietf.org/html/rfc2873
# Scraping success = True. Url:  http://tools.ietf.org/html/rfc2873
# Scraping URL:  http://www.mitec.cz/wrr.html
# Scraping success = True. Url:  http://www.mitec.cz/wrr.html
# Scraping URL:  http://stantchev.de/
# Scraping success = True. Url:  http://stantchev.de/
# Scraping URL:  http://cordis.europa.eu/infosec/src/study5.htm
# Scraping success = True. Url:  http://cordis.europa.eu/infosec/src/study5.htm
# Scraping URL:  http://1099online.com/
# Scraping success = True. Url:  http://1099online.com/
# Scraping URL:  http://www.harmonicmedia.com/
# Scraping success = True. Url:  http://www.harmonicmedia.com/
# Scraping URL:  http://www.cs.umbc.edu/
# Scraping success = True. Url:  http://www.cs.umbc.edu/
# Scraping URL:  http://groups.yahoo.com/group/deepthoughtsII/
# Scraping success = True. Url:  http://groups.yahoo.com/group/deepthoughtsII/
# Scraping URL:  http://001design.com/
# Scraping success = True. Url:  http://001design.com/
# Scraping URL:  http://www.daltonmaag.com/
# Scraping success = True. Url:  http://www.daltonmaag.com/
# Scraping URL:  http://www.faqs.org/faqs/amiga/AmiTCP-faq
# Scraping success = True. Url:  http://www.faqs.org/faqs/amiga/AmiTCP-faq
# Scraping URL:  http://www.fw-1.de/aerasec/ng/vpn-freeswan/CPNG+Linux-FreeSWAN.html
# Scraping success = True. Url:  http://www.fw-1.de/aerasec/ng/vpn-freeswan/CPNG+Linux-FreeSWAN.html
# Scraping URL:  http://www.contextures.com/tiptech.html
# Scraping success = True. Url:  http://www.contextures.com/tiptech.html
# Scraping URL:  http://www.derwood.com/
# Scraping success = False.Url:  http://www.derwood.com/
# HTTPConnectionPool(host='www.derwood.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001680526DC88>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
#
#
# Scraping URL:  http://www.openquicktime.org/
# Scraping success = True. Url:  http://www.openquicktime.org/
# Scraping URL:  http://www.searchenginejournal.com/aol-dmoz-open-directory-project/5726/
# Scraping success = True. Url:  http://www.searchenginejournal.com/aol-dmoz-open-directory-project/5726/
# Scraping URL:  http://mumps.enseeiht.fr/
# Scraping success = True. Url:  http://mumps.enseeiht.fr/
# Scraping URL:  http://www.unix-ag.uni-kl.de/~fischer/kbibtex/
# Scraping success = True. Url:  http://www.unix-ag.uni-kl.de/~fischer/kbibtex/
# Scraping URL:  http://www.siemon.com/us/white_papers/97-10-02-presentation.asp
# Scraping success = True. Url:  http://www.siemon.com/us/white_papers/97-10-02-presentation.asp
# Scraping URL:  http://guisearch.sourceforge.net/
# Scraping success = True. Url:  http://guisearch.sourceforge.net/
# Scraping URL:  http://www.qksoft.com/utility-ping/index.html
# Scraping success = True. Url:  http://www.qksoft.com/utility-ping/index.html
# Scraping URL:  http://freevo.sourceforge.net/
# Scraping success = True. Url:  http://freevo.sourceforge.net/
# Scraping URL:  http://www.media.co.uk/
# Scraping success = False.Url:  http://www.media.co.uk/
# 'NoneType' object has no attribute 'contents'
#
#
# Scraping URL:  http://www.eteklogics.com/
# Scraping success = True. Url:  http://www.eteklogics.com/
# Scraping URL:  http://www.humblesoftware.com/envision
# Scraping success = True. Url:  http://www.humblesoftware.com/envision
# Scraping URL:  http://srufaculty.sru.edu/david.dailey/public/public_domain.htm
# Scraping success = True. Url:  http://srufaculty.sru.edu/david.dailey/public/public_domain.htm
# Scraping URL:  http://www.logipole.com/indexe.html
# Scraping success = True. Url:  http://www.logipole.com/indexe.html
# Scraping URL:  http://www.projectorshawaii.com/
# Scraping success = True. Url:  http://www.projectorshawaii.com/
# Scraping URL:  http://www.catseyeweb.com/
# Scraping success = False.Url:  http://www.catseyeweb.com/
# 'NoneType' object has no attribute 'contents'
#
#
# Scraping URL:  http://www.mailchannels.com/
# Scraping success = True. Url:  http://www.mailchannels.com/
# Scraping URL:  http://www.wsnkb.com/
# Scraping success = True. Url:  http://www.wsnkb.com/
# Scraping URL:  http://ubuntustudio.org/
# Scraping success = True. Url:  http://ubuntustudio.org/
# Scraping URL:  http://www.tek-tips.com/threadminder.cfm?pid=195
# Scraping success = True. Url:  http://www.tek-tips.com/threadminder.cfm?pid=195
# Scraping URL:  http://www.webteklabs.com/
# Scraping success = True. Url:  http://www.webteklabs.com/
# Scraping URL:  http://www.powell-graphics.com/roomcal
# Scraping success = True. Url:  http://www.powell-graphics.com/roomcal
# Scraping URL:  http://www.sothink.com/product/javadecompiler/
# Scraping success = True. Url:  http://www.sothink.com/product/javadecompiler/
# Scraping URL:  http://www.oregonnetwork.com/
# Scraping success = True. Url:  http://www.oregonnetwork.com/
# Scraping URL:  http://www.altaser.com/
# Scraping success = True. Url:  http://www.altaser.com/
# Scraping URL:  http://radio-weblogs.com/0120124/2003/07/29.html
# Scraping success = True. Url:  http://radio-weblogs.com/0120124/2003/07/29.html
# Scraping URL:  https://packagecontrol.io/search/javascript
# Scraping success = True. Url:  https://packagecontrol.io/search/javascript
# Scraping URL:  https://www.xml-sitemaps.com/validate-xml-sitemap.html
# Scraping success = True. Url:  https://www.xml-sitemaps.com/validate-xml-sitemap.html
# Scraping URL:  http://www.lilug.org/
# Scraping success = False.Url:  http://www.lilug.org/
# 'NoneType' object has no attribute 'contents'
#
#
# Scraping URL:  http://www.mouseclicks.com/
# Scraping success = True. Url:  http://www.mouseclicks.com/
# Scraping URL:  http://cyber.law.harvard.edu/icann/la2000/archive/
# Scraping success = True. Url:  http://cyber.law.harvard.edu/icann/la2000/archive/
# Scraping URL:  http://cristal.inria.fr/whizzytex/
# Scraping success = True. Url:  http://cristal.inria.fr/whizzytex/
# Scraping URL:  http://www.lowgmarketing.com/
# Scraping success = True. Url:  http://www.lowgmarketing.com/
# Scraping URL:  http://www.pnotepad.org/
# Scraping success = True. Url:  http://www.pnotepad.org/
# Scraping URL:  http://www.michelleotoole.com/
# Scraping success = True. Url:  http://www.michelleotoole.com/
# Scraping URL:  http://www.must.de/default.html?cameleon.html
# Scraping success = True. Url:  http://www.must.de/default.html?cameleon.html
# Scraping URL:  http://www.prgdesign.com/
# Scraping success = True. Url:  http://www.prgdesign.com/
# Scraping URL:  http://www.iisprotect.com/
# Scraping success = True. Url:  http://www.iisprotect.com/
# Scraping URL:  http://tools.ietf.org/html/rfc2668
# Scraping success = True. Url:  http://tools.ietf.org/html/rfc2668
# Scraping URL:  http://www.serveradmins.biz/
# Scraping success = False.Url:  http://www.serveradmins.biz/
# HTTPConnectionPool(host='www.serveradmins.biz', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000
# Scraping success = True. Url:  http://www.zuccaralloo.de/devgroup/
# Scraping URL:  http://www.google.com/landing/2step/
# Scraping success = True. Url:  http://www.google.com/landing/2step/
# Scraping URL:  http://www.wintellect.com/
# Scraping success = True. Url:  http://www.wintellect.com/
# Scraping URL:  http://www.blogbinders.com/
# Scraping success = True. Url:  http://www.blogbinders.com/
# Scraping URL:  http://www.prospero.org/
# Scraping success = True. Url:  http://www.prospero.org/
# Scraping URL:  http://www.edgewebhosting.net/
# Scraping success = True. Url:  http://www.edgewebhosting.net/
# Scraping URL:  http://www.miranda-im.org/
# Scraping success = True. Url:  http://www.miranda-im.org/
# Scraping URL:  http://tools.ietf.org/html/rfc1962
# Scraping success = True. Url:  http://tools.ietf.org/html/rfc1962
# Scraping URL:  http://www.mgshareware.com/
# Scraping success = True. Url:  http://www.mgshareware.com/
# Scraping URL:  http://matemedia.com/
# Scraping success = True. Url:  http://matemedia.com/
# Scraping URL:  http://www.coolcomputercases.com/
# Scraping success = True. Url:  http://www.coolcomputercases.com/
# Scraping URL:  http://www.ubcc.com/
# Scraping success = True. Url:  http://www.ubcc.com/
# Scraping URL:  http://www.openwatcom.org/
# Scraping success = True. Url:  http://www.openwatcom.org/
# Scraping URL:  http://www.cnet.com/news/the-week-in-review-aols-message-in-a-copyright-battle/
# Scraping success = True. Url:  http://www.cnet.com/news/the-week-in-review-aols-message-in-a-copyright-battle/
# Scraping URL:  http://www.datastrat.com/
# Scraping success = True. Url:  http://www.datastrat.com/
# Scraping URL:  http://www.cordiant.com/
# Scraping success = False.Url:  http://www.cordiant.com/
# HTTPSConnectionPool(host='www.cordiant.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
#
# Scraping URL:  http://www.gamefaqs.com/psp/921495-burnout-legends/data
# Scraping success = True. Url:  http://www.gamefaqs.com/psp/921495-burnout-legends/data
# Scraping URL:  http://www.ign.com/games/the-ant-bully/ps2-763831
# Scraping success = True. Url:  http://www.ign.com/games/the-ant-bully/ps2-763831
# Scraping URL:  http://www.infocom-if.org/games/hhgttg/hhgttg.html
# Scraping success = True. Url:  http://www.infocom-if.org/games/hhgttg/hhgttg.html
# Scraping URL:  http://website.lineone.net/~rwein/blitz/blitzclar.htm
# Scraping success = False.Url:  http://website.lineone.net/~rwein/blitz/blitzclar.htm
# HTTPConnectionPool(host='website.lineone.net', port=80): Max retries exceeded with url: /~rwein/blitz/blitzclar.htm (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000016804FE9E80>, 'Connection to website.lineone.net timed out. (connect timeout=10)'))
#
#
# Scraping URL:  http://www.cheatcc.com/dc/wsbb2002.html
# Scraping success = True. Url:  http://www.cheatcc.com/dc/wsbb2002.html
# Scraping URL:  http://www.gamedemo.com/
# Scraping success = True. Url:  http://www.gamedemo.com/
# Scraping URL:  http://slashdot.org/story/00/06/04/1525259/shadowrunning-in-the-corporate-republic
# Scraping success = True. Url:  http://slashdot.org/story/00/06/04/1525259/shadowrunning-in-the-corporate-republic
# Scraping URL:  http://www.showdowncards.com/
# Scraping success = True. Url:  http://www.showdowncards.com/
# Scraping URL:  http://www.worldsfair.co.uk/
('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
#
# Scraping URL:  http://www.cheatcc.com/n64/armymen_sh2.html
# Scraping success = True. Url:  http://www.cheatcc.com/n64/armymen_sh2.html
# Scraping URL:  http://ds.ign.com/objects/801/801058.html
# Scraping success = True. Url:  http://ds.ign.com/objects/801/801058.html
# Scraping URL:  http://www.gsolace.wowstead.com/
# Scraping success = False.Url:  http://www.gsolace.wowstead.com/
# HTTPSConnectionPool(host='www.gsolace.wowstead.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
#
# ...
# Scraping URL:  http://www.askergoworks.com/
# Scraping success = True. Url:  http://www.askergoworks.com/
# Scraping URL:  http://www.yeshuasportswear.com/
# Scraping success = True. Url:  http://www.yeshuasportswear.com/
# Scraping URL:  http://www.canadamounts.com/
# Scraping success = True. Url:  http://www.canadamounts.com/
# Scraping URL:  http://www.smithandalexander.com/
# Scraping success = True. Url:  http://www.smithandalexander.com/
# Scraping URL:  http://www.mailordercomics.com/
# Scraping success = True. Url:  http://www.mailordercomics.com/
# Scraping URL:  http://idjnow.com/
# Scraping success = True. Url:  http://idjnow.com/
# Scraping URL:  http://www.fairhavenbaptist.org/
# Scraping success = True. Url:  http://www.fairhavenbaptist.org/
# Scraping URL:  http://leonia.church/
# Scraping success = False.Url:  http://leonia.church/
# HTTPSConnectionPool(host='leonia.church', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
#
# Scraping URL:  http://www.hungersolutions.org/
# Scraping success = True. Url:  http://www.hungersolutions.org/
# Scraping URL:  http://calvarychapelnorristown.org/
# Scraping success = True. Url:  http://calvarychapelnorristown.org/
# Scraping URL:  http://www.jm3.net/
# Scraping success = True. Url:  http://www.jm3.net/
# Scraping URL:  http://www.goatrance.de/goabase/
# Scraping success = False.Url:  http://www.goatrance.de/goabase/
# HTTPSConnectionPool(host='www.goatrance.de', port=443): Max retries exceeded with url: /goabase/ (Caused by SSLError(CertificateError("hostname 'www.goatrance.de' doesn't match either of 'pma.goabase.net', 'www.goabase.net'",),))
#
#
# Scraping URL:  http://www.fumcventura.org/
# Scraping success = False.Url:  http://www.fumcventura.org/
# HTTPConnectionPool(host='www.fumcventura.org', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000168052EC898>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed',))
#
#
# Scraping URL:  http://www.bestyears.com/
# Scraping success = True. Url:  http://www.bestyears.com/
# Scraping URL:  http://www.angelfire.com/cantina/visithra/
# Scraping success = True. Url:  http://www.angelfire.com/cantina/visithra/
# Scraping URL:  http://www.stmarkomaha.org/
# Scraping success = True. Url:  http://www.stmarkomaha.org/
# Scraping URL:  http://csdb-gilliland.blogspot.com/
# Scraping success = True. Url:  http://csdb-gilliland.blogspot.com/
# Scraping URL:  http://www.newadvent.org/cathen/05115a.htm
# Scraping success = True. Url:  http://www.newadvent.org/cathen/05115a.htm
# Scraping URL:  http://www.isle-lions.org.uk/
# Scraping success = True. Url:  http://www.isle-lions.org.uk/
# Scraping URL:  http://www.mhanation.com/
# Scraping success = True. Url:  http://www.mhanation.com/
# Scraping URL:  http://www.nytimes.com/2001/09/16/nyregion/16FUNE.html
# Scraping success = True. Url:  http://www.nytimes.com/2001/09/16/nyregion/16FUNE.html
# Scraping URL:  http://www.truthseekers.org/
# Scraping success = True. Url:  http://www.truthseekers.org/
# Scraping URL:  http://trinitypella.org/
# Scraping success = True. Url:  http://trinitypella.org/
# Scraping URL:  http://www.thomasmertonsociety.org.uk/
# Scraping success = True. Url:  http://www.thomasmertonsociety.org.uk/
# Scraping URL:  http://www.newadvent.org/cathen/09435a.htm
# Scraping success = True. Url:  http://www.newadvent.org/cathen/09435a.htm
# Scraping URL:  http://www.swedenborg.org/
# Scraping success = True. Url:  http://www.swedenborg.org/
# Scraping URL:  http://www.atlantaapologist.org/
# Scraping success = True. Url:  http://www.atlantaapologist.org/
# Scraping URL:  http://www.oppf.org/
# Scraping success = True. Url:  http://www.oppf.org/
# Scraping URL:  http://freepages.genealogy.rootsweb.ancestry.com/~djhelmer/
# Scraping success = True. Url:  http://freepages.genealogy.rootsweb.ancestry.com/~djhelmer/
# Scraping URL:  http://www.warnermemorial.org/
# Scraping success = True. Url:  http://www.warnermemorial.org/
# Scraping URL:  http://www.alaska-kofc.org/01992A/
# Scraping success = True. Url:  http://www.alaska-kofc.org/01992A/
# Scraping URL:  http://www.dhushara.com/
# Scraping success = True. Url:  http://www.dhushara.com/
# Scraping URL:  http://www.newberryarp.org/
# Scraping success = True. Url:  http://www.newberryarp.org/
# Scraping URL:  http://www.nesl.edu/library/
# Scraping success = True. Url:  http://www.nesl.edu/library/
# Scraping URL:  http://www.amer-law.com/
# Scraping success = True. Url:  http://www.amer-law.com/
# Scraping URL:  http://www.siddhayoga.org/
# Scraping success = True. Url:  http://www.siddhayoga.org/
# Scraping URL:  http://www.trufax.org/matrix5/welcome.html
# Scraping success = True. Url:  http://www.trufax.org/matrix5/welcome.html
# Scraping URL:  http://www.theonetruth.org/
# Scraping success = True. Url:  http://www.theonetruth.org/
# Scraping URL:  http://www.fourdir.com/pennacook.htm
# Scraping success = False.Url:  http://www.fourdir.com/pennacook.htm
# 'NoneType' object has no attribute 'contents'
#
#
# Scraping URL:  http://www.salemcovpennock.org/
# Scraping success = True. Url:  http://www.salemcovpennock.org/
# Scraping URL:  http://webpages.charter.net/sgiuc/
# Scraping success = False.Url:  http://webpages.charter.net/sgiuc/
# HTTPConnectionPool(host='webpages.charter.net', port=80): Max retries exceeded with url: /sgiuc/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000016804F5CB70>, 'Connection to webpages.charter.net timed out. (connect timeout=10)'))
#
#
# Scraping URL:  http://www.newadvent.org/cathen/05510b.htm
# Scraping success = True. Url:  http://www.newadvent.org/cathen/05510b.htm
# Scraping URL:  http://www.evangelist-rogerwhipp.org/
# Scraping success = True. Url:  http://www.evangelist-rogerwhipp.org/
# Scraping URL:  http://www.cathar.info/121211_heisterbach.htm
# Scraping success = True. Url:  http://www.cathar.info/121211_heisterbach.htm
# Scraping URL:  http://www.homenetmen.net/
# Scraping success = True. Url:  http://www.homenetmen.net/
# Scraping URL:  http://roaming.op351.com/
# Scraping success = True. Url:  http://roaming.op351.com/
# Scraping URL:  http://www.policyalmanac.org/social_welfare/archive/unemployment_compensation.shtml
# Scraping success = False.Url:  http://www.policyalmanac.org/social_welfare/archive/unemployment_compensation.shtml
# HTTPConnectionPool(host='www.policyalmanac.org', port=80): Max retries exceeded with url: /social_welfare/archive/unemployment_compensation.shtml (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001686BF5F7F0>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed',))
#
#
# Scraping URL:  http://cityofprayer.tripod.com/
# Scraping success = True. Url:  http://cityofprayer.tripod.com/
# Scraping URL:  http://www.haleem.com/
# Scraping success = True. Url:  http://www.haleem.com/
# Scraping URL:  http://www.shabbir.com/romance/bday.html
# Scraping success = True. Url:  http://www.shabbir.com/romance/bday.html
# Scraping URL:  http://www.trinityhills.org.au/
# Scraping success = False.Url:  http://www.trinityhills.org.au/
# HTTPConnectionPool(host='www.trinityhills.org.au', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000016803E59E48>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
#
#
# Scraping URL:  http://www.newadvent.org/cathen/09636b.htm
# Scraping success = True. Url:  http://www.newadvent.org/cathen/09636b.htm
# Scraping URL:  http://www.stbrn.ac.uk/
# Scraping success = True. Url:  http://www.stbrn.ac.uk/
# Scraping URL:  http://www.newadvent.org/cathen/02203a.htm
# Scraping success = True. Url:  http://www.newadvent.org/cathen/02203a.htm
# Scraping URL:  http://wc.rootsweb.ancestry.com/cgi-bin/igm.cgi?db=tibart
# Scraping success = True. Url:  http://wc.rootsweb.ancestry.com/cgi-bin/igm.cgi?db=tibart
# Scraping URL:  http://uscobm.com/
# Scraping success = True. Url:  http://uscobm.com/
# Scraping URL:  http://www.lcemmaus.org/
# Scraping success = True. Url:  http://www.lcemmaus.org/
# Scraping URL:  http://www.esperienzediluce.com/
# Scraping success = True. Url:  http://www.esperienzediluce.com/
# Scraping URL:  http://www.earlham.edu/~peters/courses/logsys/satisfac.htm
# Scraping success = False.Url:  http://www.earlham.edu/~peters/courses/logsys/satisfac.htm
# HTTPSConnectionPool(host='earlham.edu', port=443): Max retries exceeded with url: /~peters/courses/logsys/satisfac.htm (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
#
# Scraping URL:  http://www.christianlyricsonline.com/
# Scraping success = True. Url:  http://www.christianlyricsonline.com/
# Scraping URL:  http://plato.stanford.edu/entries/feminism-femhist/
# Scraping success = False.Url:  http://plato.stanford.edu/entries/feminism-femhist/
# HTTPSConnectionPool(host='plato.stanford.edu', port=443): Max retries exceeded with url: /entries/feminism-femhist/ (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
#
# Scraping URL:  http://www.armeniangenocidedebate.com/
# Scraping success = True. Url:  http://www.armeniangenocidedebate.com/
# Scraping URL:  http://www.gourd.com/123A.HTML
# Scraping success = True. Url:  http://www.gourd.com/123A.HTML
# Scraping URL:  http://www.sunsetlodge915.com/
# Scraping success = True. Url:  http://www.sunsetlodge915.com/
# Scraping URL:  http://www.spfbc.com/
# Scraping success = True. Url:  http://www.spfbc.com/
# Scraping URL:  http://www.legalstaff.com/
# Scraping success = True. Url:  http://www.legalstaff.com/
# Scraping URL:  http://cbctexas.org/
# Scraping success = True. Url:  http://cbctexas.org/
# Scraping URL:  http://www.ectorbaptist.org/
# Scraping success = True. Url:  http://www.ectorbaptist.org/
# Scraping URL:  http://holyrosaryparish.com/
# Scraping success = True. Url:  http://holyrosaryparish.com/
# Scraping URL:  http://carrboro.com/powwow.html
# Scraping success = True. Url:  http://carrboro.com/powwow.html
# Scraping URL:  http://www.shreemaa.org/devi-gita-book/
# Scraping success = True. Url:  http://www.shreemaa.org/devi-gita-book/
# Scraping URL:  http://www.deathcamps.org/belzec/
# Scraping success = True. Url:  http://www.deathcamps.org/belzec/
# Scraping URL:  http://plato.stanford.edu/entries/whitehead/
# Scraping success = False.Url:  http://plato.stanford.edu/entries/whitehead/
# HTTPSConnectionPool(host='plato.stanford.edu', port=443): Max retries exceeded with url: /entries/whitehead/ (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
#
# Scraping URL:  http://www.gay-hike.com/home.htm
# Scraping success = True. Url:  http://www.gay-hike.com/home.htm
# Scraping URL:  http://www.messiahlutheran.ws/
# Scraping success = True. Url:  http://www.messiahlutheran.ws/
# Scraping URL:  http://catholicsaints.info/pope-saint-callistus-i/
# Scraping success = True. Url:  http://catholicsaints.info/pope-saint-callistus-i/
# Scraping URL:  http://www.jesconsulting.com/
# Scraping success = True. Url:  http://www.jesconsulting.com/
# Scraping URL:  http://www.hollisteradventist.org/
# Scraping success = False.Url:  http://www.hollisteradventist.org/
# HTTPConnectionPool(host='www.hollisteradventist.org', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000016803CCEC88>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
#
#
# Scraping URL:  http://www.genuinereaders.com/
# Scraping success = True. Url:  http://www.genuinereaders.com/
# Scraping URL:  http://www.newadvent.org/cathen/01618a.htm
# Scraping success = True. Url:  http://www.newadvent.org/cathen/01618a.htm
# Scraping URL:  http://www.mcgill.ca/terraferma/
# Scraping success = True. Url:  http://www.mcgill.ca/terraferma/
# Scraping URL:  http://www.angelfire.com/hi/Azgaser/hindus.html
# Scraping success = True. Url:  http://www.angelfire.com/hi/Azgaser/hindus.html
# Scraping URL:  http://www.angelfire.com/nh/TavernOfTheBlueRose/
# Scraping success = True. Url:  http://www.angelfire.com/nh/TavernOfTheBlueRose/
# Scraping URL:  http://www.starlodge115.org/
# Scraping success = False.Url:  http://www.starlodge115.org/
# 'NoneType' object has no attribute 'contents'
#
#
# Scraping URL:  http://www.npr.org/templates/story/story.php?storyId=1122753
# Scraping success = True. Url:  http://www.npr.org/templates/story/story.php?storyId=1122753
# Scraping URL:  http://www.newadvent.org/cathen/06541a.htm
# Scraping success = True. Url:  http://www.newadvent.org/cathen/06541a.htm
# Scraping URL:  http://www.nrcprograms.org/
# Scraping success = True. Url:  http://www.nrcprograms.org/
# Scraping URL:  http://www.kiddlawfirm.com/
# Scraping success = True. Url:  http://www.kiddlawfirm.com/
# Scraping URL:  http://tm35.toastmastersdistricts.org/
# Scraping success = True. Url:  http://tm35.toastmastersdistricts.org/
# Scraping URL:  http://www.theotherpages.org/quote-05.html
# Scraping success = True. Url:  http://www.theotherpages.org/quote-05.html
# Scraping URL:  http://www.friendsinchrist.net/
# Scraping success = True. Url:  http://www.friendsinchrist.net/
# Scraping URL:  http://www.paganpartners.co.uk/
# Scraping success = False.Url:  http://www.paganpartners.co.uk/
# HTTPSConnectionPool(host='www.paganpartners.co.uk', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
#
# Scraping URL:  http://mondediplo.com/2002/02/08tendays
# Scraping success = True. Url:  http://mondediplo.com/2002/02/08tendays
# Scraping URL:  http://www.thefirstamendment.org/
# Scraping success = False.Url:  http://www.thefirstamendment.org/
# HTTPSConnectionPool(host='www.thefirstamendment.org', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
#
# Scraping URL:  http://www.robbooth.net/
# Scraping success = True. Url:  http://www.robbooth.net/
# Scraping URL:  http://www.crosspurposes.ca/
# Scraping success = True. Url:  http://www.crosspurposes.ca/
# Scraping URL:  http://www.michaelsharp.org/
# Scraping success = True. Url:  http://www.michaelsharp.org/
# Scraping URL:  http://www.svamcentral.org/
# Scraping success = False.Url:  http://www.svamcentral.org/
# HTTPConnectionPool(host='www.svamcentral.org', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001680389ABE0>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed',))
#
#
# Scraping URL:  http://stgeorgesos.ca/
# Scraping success = True. Url:  http://stgeorgesos.ca/
# Scraping URL:  http://www.dharma-haven.org/tibetan/karmapa-xvii.htm
# Scraping success = False.Url:  http://www.dharma-haven.org/tibetan/karmapa-xvii.htm
# 'NoneType' object has no attribute 'contents'
#
#
# Scraping URL:  http://www.newadvent.org/cathen/04131a.htm
# Scraping success = True. Url:  http://www.newadvent.org/cathen/04131a.htm
# Scraping URL:  http://www.mmt-kmi.com/
# Scraping success = True. Url:  http://www.mmt-kmi.com/
# Scraping URL:  http://www.sarasotagermanclub.org/
# Scraping success = True. Url:  http://www.sarasotagermanclub.org/
# Scraping URL:  http://therainbowbabies.com/
# Scraping success = True. Url:  http://therainbowbabies.com/
# Scraping URL:  http://www.trinity.edu/cbrown/papers/belstates&narcon.html
# Scraping success = False.Url:  http://www.trinity.edu/cbrown/papers/belstates&narcon.html
# HTTPSConnectionPool(host='new.trinity.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
#
# Scraping URL:  http://www.exlc.org/
# Scraping success = True. Url:  http://www.exlc.org/

# %%
scraped_websites_df = pd.DataFrame(pd.concat(series_list,axis=1,sort=False)).T

# %% [markdown]
# ## Let's join the scraped table with the dmoz website dataframe

# %%
scraped_websites_df = websites_df_subset.merge(scraped_websites_df,left_on="Sites",right_on="website_url")

# %%
scraped_websites_df.to_pickle("./pkl_files/dmoz_subset_956_sites_scraped.pkl")

# %%
scraped_websites_df.columns
# Out:
# Index(['index', 'Description', 'Title', 'URL', 'Sites', 'CCat', 'MCat', 'SCat',
#        'website_url', 'website_name',
#        ...
#        'tag_count_mark', 'tag_count_v:shape', 'tag_count_v:imagedata',
#        'tag_count_w:wrap', 'tag_count_href', 'tag_count_audio',
#        'tag_count_hardpoint', 'tag_count_nolayer', 'tag_count_ilayer',
#        'tag_count_align'],
#       dtype='object', length=253)

# %% [markdown]
# ### This is the final dataframe for the website.
